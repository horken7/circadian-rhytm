# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %matplotlib inline

# %% [markdown]
# # what we have done
#
# * plot the magnitude of the acceleration against time
# * from the magnitude of the acceleration we worked out the angle of the arm
#     * (which means we have a displacement measure in angle form)
#     * we then measured the standard deviation for the arm angle
#         * this standard deviation stands for the amount of movement (i think)
#
#
# * Note : standard deviation may not be the best measure, since it works out the mean and calculates how far from the mean. Another approach could
#
#
# # Task aims
# * is our goal to detect REM sleep?

# %%
# load file approach 1
# fileName = 'data_01.csv'
# df1 = pd.read_csv(fileName)

# %%
# load file approach 2
fileName0 = 'data_00.csv'
df = pd.read_csv(fileName0, index_col='datetime')
df
# Out:
#                                   cold-water  door   dust  electricity  hid  \
# datetime
# 2016-05-31 21:59:59.919856+00:00         NaN   NaN    NaN          NaN  NaN
# 2016-05-31 21:59:59.969904+00:00         NaN   NaN    NaN          NaN  NaN
# 2016-05-31 22:00:00.019952+00:00         NaN   NaN    NaN          NaN  NaN
# 2016-05-31 22:00:00.070000+00:00         NaN   NaN    NaN          NaN  NaN
# 2016-05-31 22:00:00.119856+00:00         NaN   NaN    NaN          NaN  NaN
# 2016-05-31 22:00:00.169904+00:00         NaN   NaN    NaN          NaN  NaN
# 2016-05-31 22:00:00.219952+00:00         NaN   NaN    NaN          NaN  NaN
# 2016-05-31 22:00:00.243000+00:00         NaN   NaN    NaN          NaN  1.0
# 2016-05-31 22:00:00.243000+00:00         NaN   NaN    NaN          NaN  1.0
# 2016-05-31 22:00:00.243000+00:00         NaN   NaN  0.019          NaN  1.0
# 2016-05-31 22:00:00.270000+00:00         NaN   NaN    NaN          NaN  NaN
# 2016-05-31 22:00:00.319856+00:00         NaN   NaN    NaN          NaN  NaN
# 2016-05-31 22:00:00.369904+00:00         NaN   NaN    NaN          NaN  NaN
# 2016-05-31 22:00:00.406000+00:00         NaN   NaN    NaN        286.0  1.0
# 2016-05-31 22:00:00.419952+00:00         NaN   NaN    NaN          NaN  NaN
# 2016-05-31 22:00:00.470000+00:00         NaN   NaN    NaN          NaN  NaN
# 2016-05-31 22:00:00.520856+00:00         NaN   NaN    NaN          NaN  NaN
# 2016-05-31 22:00:00.570904+00:00         NaN   NaN    NaN          NaN  NaN
# 2016-05-31 22:00:00.618000+00:00         NaN   NaN    NaN          NaN  1.0
# 2016-05-31 22:00:00.618000+00:00         NaN   NaN    NaN          NaN  1.0
# 2016-05-31 22:00:00.618000+00:00         NaN   NaN  0.175          NaN  1.0
# 2016-05-31 22:00:00.620952+00:00         NaN   NaN    NaN          NaN  NaN
# 2016-05-31 22:00:00.671000+00:00         NaN   NaN    NaN          NaN  NaN
# 2016-05-31 22:00:00.720856+00:00         NaN   NaN    NaN          NaN  NaN
# 2016-05-31 22:00:00.770904+00:00         NaN   NaN    NaN          NaN  NaN
# 2016-05-31 22:00:00.820952+00:00         NaN   NaN    NaN          NaN  NaN
# 2016-05-31 22:00:00.871000+00:00         NaN   NaN    NaN          NaN  NaN
# 2016-05-31 22:00:00.920856+00:00         NaN   NaN    NaN          NaN  NaN
# 14           28/07       23:00         23:00                            15
# 14           29/07       00:00         00:40                            20
# 14           30/07       00:00         00:00                            15
# 14           31/07       22:30         00:00                          Long
# 14           01/08       22:00         01:00                          Long
# 14           02/08       22:00         22:30                            60
# 14           03/08       23:00         00:00                            30
# 14           04/08       23:00         00:00                            60
# 14           05/08       22:00         01:00                            30
# 14           06/08       22:00         02:00                            20
# 14           07/08       21:00         21:00                             5
# 15           24/05       23:12         23:30                            10
# 15           25/05       23:10         23:30                             5
# 15           26/05       22:31         23:00                            20
# 15           27/05       22:13         23:00                            69
# 16           26/07       00:15         00:15                          5-10
# 16           27/07       00:15         00:15                          5-10
# 16           28/07       00:20         00:20                          5-10
# 17           16/08       10:45         11:15                           180
# 17           17/08       10:55         11:15                           180
# 18           16/08       11:00         12:30                        60- 90
# 18           17/08       11:00         01:30                            60
# 19           06/08       00:00         00:00                             0
# 19           07/08       00:00         00:00                             5
# 19           08/08       23:00         23:10                             5
# 21           08/10       23:15         23:15                            15
# 21           09/10       00:15         00:45                            30
#
#             Wake up time Time to get up Quality of Sleep How Refreshed  \
# Participant
# 1                  07:00          07:00             Poor      Somewhat
# 1                  06:30          06:30             Fair      Somewhat
# 1                  07:00          07:00             Fair      Somewhat
# 14                 08:20          08:25             Fair     Refreshed
# 14                 07:55          08:00             Fair     Refreshed
# 14                 08:50          08:50             Good     Refreshed
# 14                 08:40          10:00        Very Good     Refreshed
# 14                 10:00          10:15        Very Good     Refreshed
# 14                 08:20          08:20             Good     Refreshed
# 14                 08:00          08:00        Very Good      Somewhat
# 14                 08:10          08:10        Very Good     Refreshed
# 14                 08:10          08:10        Very Good     Refreshed
# 14                 08:00          08:00        Very Good     Refreshed
# 14                 09:30          10:00             Good      Somewhat
# 14                 10:00          10:00             Fair      Somewhat
# 14                 08:00          08:30             Fair      Somewhat
# 14                 08:40          09:00             Fair      Somewhat
# 14                 08:40          08:50             Good      Somewhat
# 14                 09:00          09:00             Good      Somewhat
# 14                 09:00          09:00             Good      Somewhat
# 14                 06:30          07:00             Good      Somewhat
# 14                 07:30          08:00             Good          Very
# 15                 06:20          06:28             Fair      Slightly
# 15                 06:30          06:37             Good      Somewhat
# 15                 07:00          07:06             Fair      Somewhat
# 15                 06:30          06:30             Poor      Slightly
# 16                 05:00          08:20             Poor      Slightly
# 16                 08:00          08:00             Good     Refreshed
# 16                 05:00          08:00             Fair      Somewhat
# 17                 06:00          07:50             Poor      Somewhat
# 17                 06:00          07:20             Poor      Somewhat
# 18                 10:40          11:00             Fair     Refreshed
# 18                 08:45          08:55             Good     Refreshed
# 19                 10:00          10:10             Good     Refreshed
# 19                 08:00          08:10        Very Good     Refreshed
# 19                 08:00          08:10             Good      Somewhat
# 21                 08:00          08:20             Good     Refreshed
# 21                 08:00          08:30             Fair      Somewhat
#
#             Normal Night                                           Comments
# Participant
# 1                    Yes                                                  -
# 1                    Yes                                                  -
# 1                    Yes                                                  -
# 14                    No           woken by very noisy birds in the morning
# 14                    No                    Car alarm went off in the night
# 14                   Yes                                                NaN
# 14                   Yes                                                NaN
# 14                   Yes                                                NaN
# 14                   Yes                                                NaN
# 14                   Yes                                                NaN
# 14                   Yes                                                NaN
# 14                   Yes                                                NaN
# 14                   Yes                                                NaN
# 14                   Yes                                                NaN
# 14                    No                          It was loud on the street
# 14                    No                          It was loud on the street
# 14                    No                                Couldn't sleep well
# 14                   Yes                                                NaN
# 14                   Yes                                                NaN
# 14                   Yes                                                NaN
# 14                   Yes                                                NaN
# 14                   Yes                                                NaN
# 15                    No                                                NaN
# 15                  Yes                                                 NaN
# 15                   Yes                                                NaN
# 15                    No                                                NaN
# 16                    No  The bed was harder than I'm used to and it hur...
# 16                   Yes  Used two pillows and an airplane sleeping mat ...
# 16                   Yes                            Forgot the sleeping mat
# 17                    No  I got very hot and opened the window. Suffered...
# 17                    No                 No idea why - Just didn't drop off
# 18                   Yes                                                NaN
# 18                   Yes                                                NaN
# 19                   Yes                                                NaN
# 19                   Yes                                                NaN
# 19                   Yes                                                NaN
# 21                   Yes                                                NaN
# 21                    No  Normally I sleep very well and I awoke several...

# %%
# magnitude of acceleration
magnitude = df['wearable-mag-xl1']
datetime = pd.to_datetime(df.index)

fig = plt.figure(figsize=(15,10))
ax = fig.add_subplot(111)
ax.set_ylabel('Magnitude of acceleration')
ax.set_xlabel('Time')
ax.plot(datetime, magnitude)

# %%
# raw accelerometer data
accelerometer_directions = df[['wearable-xl1-x', 'wearable-xl1-y', 'wearable-xl1-z']]

# get rid of rows with missing values
accelerometer_directions = accelerometer_directions.dropna()
datetime = pd.to_datetime(accelerometer_directions.index)

# arm angle calculation using accelerometer data
accelerometer_directions['angle'] = 180/np.pi * np.arctan(accelerometer_directions['wearable-xl1-z'] / np.sqrt( np.square(accelerometer_directions['wearable-xl1-x']) + np.square(accelerometer_directions['wearable-xl1-z']) ))

fig = plt.figure(figsize=(15,10))
ax = fig.add_subplot(111)
ax.set_ylabel('arm angle [degrees]')
ax.set_xlabel('time')
ax.plot(datetime, accelerometer_directions['angle'])

# %% [markdown]
# model for arm angle:  $$ \theta_{\text{arm}} = tan^{-1} \bigg(\frac{ a_{z} }{ \sqrt{a_{x}^{2} + a_{y}^{2}} } \bigg) $$

# %%
# convert index to DatetimeIndex
accelerometer_directions.index = pd.DatetimeIndex(accelerometer_directions.index)

# resample with 5 min interval
resample_5min_accel = accelerometer_directions.resample('5Min')


fig = plt.figure(figsize=(15,10))
ax = fig.add_subplot(111)
ax.set_title('Arm angle std with 5 min resampling')
ax.set_ylabel('std')
ax.set_ylabel('time')
ax.plot(resample_5min_accel.index, resample_5min_accel.std()['angle'])
# Out:
# //anaconda/lib/python3.6/site-packages/ipykernel/__main__.py:13: FutureWarning:
# .resample() is now a deferred operation
# You called index(...) on this deferred object which materialized it into a dataframe
# by implicitly taking the mean.  Use .resample(...).mean() instead

# %%
def classify(val):
    zone0 = 3
    zone1 = 6
    zone2 = 10
    zone3 = 20
    if(val <= zone0):
        return 0
    elif(val > zone0 and val <= zone1):
        return 1
    elif(val > zone1 and val <= zone2):
        return 2 
    elif(val > zone2 and val <= zone3):
        return 3
    else:
        return 4
    
ind = resample_5min_accel.index
std = accelerometer_directions.resample('5Min').std()['angle']
classification = []
for i, val in enumerate(std.values):
    classification.append(classify(val))
    
print('Time in Zone0: '+str((classification.count(0)*5)/60)+'h')
print('Time in Zone1: '+str((classification.count(1)*5)/60)+'h')
print('Time in Zone2: '+str((classification.count(2)*5)/60)+'h')
print('Time in Zone3: '+str((classification.count(3)*5)/60)+'h')
print('Time in Zone4: '+str((classification.count(4)*5)/60)+'h')
print('Total time in bed: '+str(len(classification)*5/60)+'h')

print(classification.count(4)/len(classification))
    
plt.figure(1)
fig = plt.figure(figsize=(15,10))
ax = fig.add_subplot(111)
ax.set_title('Classified arm angle std')
ax.set_ylabel('time')
ax.set_ylabel('arm angle std')
colors = ['r','g','b','y','c']
for i, n in enumerate(std):
    plt.plot(ind[i], std[i], 'o', c=colors[classification[i]])
import matplotlib.patches as mpatches
import matplotlib.pyplot as plt

red_patch = mpatches.Patch(color='red', label='Zone1: std <= 3')
green_patch = mpatches.Patch(color='green', label='Zone2: 3 < std <= 6')
blue_patch = mpatches.Patch(color='blue', label='Zone3: 6 < std <= 10')
yellow_patch = mpatches.Patch(color='yellow', label='Zone4: 10 < std <= 20')
cyan_patch = mpatches.Patch(color='cyan', label='Zone5: std > 20')
plt.legend(handles=[red_patch, green_patch, blue_patch, yellow_patch ,cyan_patch])
plt.legend()
plt.show()
# Out:
# //anaconda/lib/python3.6/site-packages/ipykernel/__main__.py:17: FutureWarning:
# .resample() is now a deferred operation
# You called index(...) on this deferred object which materialized it into a dataframe
# by implicitly taking the mean.  Use .resample(...).mean() instead
# Time in Zone0: 6.5h
# Time in Zone1: 0.5833333333333334h
# Time in Zone2: 0.6666666666666666h
# Time in Zone3: 0.8333333333333334h
# Time in Zone4: 0.9166666666666666h
# Total time in bed: 9.5h
# 0.09649122807017543
# //anaconda/lib/python3.6/site-packages/matplotlib/axes/_axes.py:545: UserWarning: No labelled objects found. Use label='...' kwarg on individual plots.
#   warnings.warn("No labelled objects found. "

# %%
deviation_5min = resample_5min_accel['angle'].max()-resample_5min_accel['angle'].min()
mean_5min = resample_5min_accel.mean()

fig = plt.figure(figsize=(15,10))
ax = fig.add_subplot(111)
ax.set_title('Arm angle with 5 min resampling')
ax.set_ylabel('arm angle')
ax.plot(resample_5min_accel.index, deviation_5min)
ax.plot(resample_5min_accel.index, mean_5min['angle'])
lines, labels = ax.get_legend_handles_labels()
ax.legend(lines[:], ['Maximum movement', 'Mean angle'], loc='best')
# Out:
# //anaconda/lib/python3.6/site-packages/ipykernel/__main__.py:8: FutureWarning:
# .resample() is now a deferred operation
# You called index(...) on this deferred object which materialized it into a dataframe
# by implicitly taking the mean.  Use .resample(...).mean() instead
# //anaconda/lib/python3.6/site-packages/ipykernel/__main__.py:9: FutureWarning:
# .resample() is now a deferred operation
# You called index(...) on this deferred object which materialized it into a dataframe
# by implicitly taking the mean.  Use .resample(...).mean() instead

# %%
classification = []
for ind, val in enumerate(deviation_5min.values):
    classification.append(classify(val))

plt.figure(1)
fig = plt.figure(figsize=(15,10))
ax = fig.add_subplot(111)
ax.set_title('Classified arm angle deviation over 5min intervals')
ax.set_ylabel('arm angle')
ax.set_ylabel('time')
colors = ['r','g','b','y','c']
ind = deviation_5min.index
for i, n in enumerate(deviation_5min):
    plt.plot(ind[i], n, 'o', c=colors[classification[i]])
red_patch = mpatches.Patch(color='red', label='Zone1: angle <= 3')
green_patch = mpatches.Patch(color='green', label='Zone2: 3 < angle <= 6')
blue_patch = mpatches.Patch(color='blue', label='Zone3: 6 < angle <= 10')
yellow_patch = mpatches.Patch(color='yellow', label='Zone4: 10 < angle <= 20')
cyan_patch = mpatches.Patch(color='cyan', label='Zone5: angle > 20')
plt.legend(handles=[red_patch, green_patch, blue_patch, yellow_patch ,cyan_patch])
plt.legend()
# Out:
# //anaconda/lib/python3.6/site-packages/matplotlib/axes/_axes.py:545: UserWarning: No labelled objects found. Use label='...' kwarg on individual plots.
#   warnings.warn("No labelled objects found. "

# %%
fig = plt.figure(figsize=(15,10))
ax = fig.add_subplot(111)
ax.set_title('Arm angle with 5 min resampling')
ax.set_ylabel('arm angle')
time = resample_5min_accel.index
mean = accelerometer_directions.resample('5Min').mean()['angle']
std = accelerometer_directions.resample('5Min').std()['angle']
print(time)
plt.errorbar(time,mean,std,linestyle='None', marker='s', mfc='b',
         mec='b', ms=5, c='r')
# Out:
# DatetimeIndex(['2016-05-31 21:55:00', '2016-05-31 22:00:00',
#                '2016-05-31 22:05:00', '2016-05-31 22:10:00',
#                '2016-05-31 22:15:00', '2016-05-31 22:20:00',
#                '2016-05-31 22:25:00', '2016-05-31 22:30:00',
#                '2016-05-31 22:35:00', '2016-05-31 22:40:00',
#                ...
#                '2016-06-01 06:35:00', '2016-06-01 06:40:00',
#                '2016-06-01 06:45:00', '2016-06-01 06:50:00',
#                '2016-06-01 06:55:00', '2016-06-01 07:00:00',
#                '2016-06-01 07:05:00', '2016-06-01 07:10:00',
#                '2016-06-01 07:15:00', '2016-06-01 07:20:00'],
#               dtype='datetime64[ns]', name='datetime', length=114, freq='5T')
# //anaconda/lib/python3.6/site-packages/ipykernel/__main__.py:5: FutureWarning:
# .resample() is now a deferred operation
# You called index(...) on this deferred object which materialized it into a dataframe
# by implicitly taking the mean.  Use .resample(...).mean() instead
# <Container object of 3 artists>

# %%
fig = plt.figure(figsize=(15,10))
ax = fig.add_subplot(111)
ax.set_title('Arm angle deviation')
ax.set_ylabel('arm angle')
ax.plot(datetime, accelerometer_directions['angle'])
ax.plot(resample_5min_accel.index, accelerometer_directions.resample('5Min').std()['angle'])
lines, labels = ax.get_legend_handles_labels()
ax.legend(lines[:], ['Arm angle', 'std arm angle'], loc='best')
# Out:
# //anaconda/lib/python3.6/site-packages/ipykernel/__main__.py:6: FutureWarning:
# .resample() is now a deferred operation
# You called index(...) on this deferred object which materialized it into a dataframe
# by implicitly taking the mean.  Use .resample(...).mean() instead

# %%
std_5min = accelerometer_directions.resample('5Min').std()['angle']
total_sleep_interval = std_5min.count()
sleep_over_std5 = std_5min[std_5min>5].count()

print(sleep_over_std5/total_sleep_interval * 100)
# Out:
# 28.9473684211

# %%
a = accelerometer_directions.resample('5Min').std()['angle']
print(a.mean())
# Out:
# 5.436828288530231

# %% [markdown]
# ### using this resampled data what can I do to detect sleep
#
#
# * over 5 min 5angle
# * work out the angle deviation
# * frequency
# * and max moved
