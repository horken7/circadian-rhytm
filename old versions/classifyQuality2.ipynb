# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from sklearn.cluster import KMeans
from sklearn import decomposition
from sklearn.neighbors import KNeighborsClassifier
from sklearn import preprocessing
import os
import pickle
import sys

# %matplotlib inline

# %%
# load sleep features
allFeatures = np.load('sleepFeatures.npy')

# %%
# normalise the values between a 0 1 range
normalisedFeatures = []
for features in allFeatures:
    min_max_scalar = preprocessing.MinMaxScaler()
    normalise = min_max_scalar.fit_transform(features)
    normalisedFeatures.append(normalise)
# Out:
# //anaconda/lib/python3.6/site-packages/sklearn/preprocessing/data.py:321: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# //anaconda/lib/python3.6/site-packages/sklearn/preprocessing/data.py:356: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# //anaconda/lib/python3.6/site-packages/sklearn/preprocessing/data.py:321: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# //anaconda/lib/python3.6/site-packages/sklearn/preprocessing/data.py:356: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# //anaconda/lib/python3.6/site-packages/sklearn/preprocessing/data.py:321: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# //anaconda/lib/python3.6/site-packages/sklearn/preprocessing/data.py:356: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# //anaconda/lib/python3.6/site-packages/sklearn/preprocessing/data.py:321: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# //anaconda/lib/python3.6/site-packages/sklearn/preprocessing/data.py:356: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# //anaconda/lib/python3.6/site-packages/sklearn/preprocessing/data.py:321: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# //anaconda/lib/python3.6/site-packages/sklearn/preprocessing/data.py:356: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# //anaconda/lib/python3.6/site-packages/sklearn/preprocessing/data.py:321: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# //anaconda/lib/python3.6/site-packages/sklearn/preprocessing/data.py:356: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# //anaconda/lib/python3.6/site-packages/sklearn/preprocessing/data.py:321: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# //anaconda/lib/python3.6/site-packages/sklearn/preprocessing/data.py:356: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# //anaconda/lib/python3.6/site-packages/sklearn/preprocessing/data.py:321: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# //anaconda/lib/python3.6/site-packages/sklearn/preprocessing/data.py:356: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# //anaconda/lib/python3.6/site-packages/sklearn/preprocessing/data.py:321: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# //anaconda/lib/python3.6/site-packages/sklearn/preprocessing/data.py:356: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)

# %%
for i in normalisedFeatures[0]:
    print(i, end=' ')
# Out:
# 0.00223164961614 0.00240187932007 0.00224218167552 0.00173031128173 0.00223700568579 0.0018842027384 0.0017103262002 0.00171185699123 0.00222481146194 0.00188633169254 0.00208792451488 0.00204225372599 0.00179478719848 0.00185070018467 0.00170464827222 0.00199079318157 0.00174978789904 0.00198700006468 0.0017178239993 0.0019889986128 0.00177226970758 0.00171926493617 0.00171808589602 0.00194148557576 0.00177161628796 0.00177613039228 0.00180038520953 0.00178282428597 0.00181521891441 0.00170464827222 0.000947831283677 0.000488598950116 0.000908619608476 0.00477912276906 0.000927641944452 0.000939096113152 0.00862465321102 0.0104378317089 0.000930209528497 0.000934040837959 0.00152105476752 0.00154055103401 0.00484485842821 0.00300424717312 0.00170464827222 0.00110886645946 0.00539573850742 0.00118887686687 0.0537599397046 0.00114831735699 0.00157238692007 0.0827710879278 0.135949097623 0.00115008862519 0.00158166226688 0.00605534654985 0.00199307645942 0.0179029149401 0.0040550704206 0.00170464827222 0.0017093726575 0.00613179690189 0.0521975363093 0.0182801916208 0.00186414809907 0.0113909187254 0.00647761378375 0.00229916971194 0.0287838221237 0.00395611954327 0.0 0.0014968530796 1.0 0.00855631406677 0.00405165245419 0.000895225306869

# %%
# search for csv location

found = []

def find(name,path):
    path = os.getcwd() + path
    file = name

    for root, dir, files in os.walk(path):
        for item in files:
            if file == item:
                return os.path.join(root, file)
        return None

# %%
# load sleep diaries

path = find('Sleep Data Research - ASD Morning.csv','/irc-sphere-sleep-56db93f64661/Sphere-csv-data/')

if path is not None:
    if 'gz' in path:
        fileName = path
        data = pd.read_csv(path, skiprows=1, index_col='Participant', compression='gzip')
    else: 
        data = pd.read_csv(path, skiprows=1, index_col='Participant')
data
# Out:
#               Date Time in Bed Time to Sleep Time to fall asleep (minutes)  \
# Participant
# 1            01/06       23:00         23:30                             5
# 1            02/06       23:30         00:00                             5
# 1            03/06       23:00         23:30                             5
# 14           20/04       23:00         23:10                            60
# 14           21/04       22:30         23:00                            60
# 14           22/04       23:30         00:30                            30
# 14           23/04       23:30         01:30                            20
# 14           24/04       23:00         01:30                            15
# 14           25/04       23:00         01:30                            60
# 14           26/07       23:30         23:30                            15
# 14           27/07       23:00         23:00                            20
# 14           28/07       23:00         23:00                            15
# 14           29/07       00:00         00:40                            20
# 14           30/07       00:00         00:00                            15
# 14           31/07       22:30         00:00                          Long
# 14           01/08       22:00         01:00                          Long
# 14           02/08       22:00         22:30                            60
# 14           03/08       23:00         00:00                            30
# 14           04/08       23:00         00:00                            60
# 14           05/08       22:00         01:00                            30
# 14           06/08       22:00         02:00                            20
# 14           07/08       21:00         21:00                             5
# 15           24/05       23:12         23:30                            10
# 15           25/05       23:10         23:30                             5
# 15           26/05       22:31         23:00                            20
# 15           27/05       22:13         23:00                            69
# 16           26/07       00:15         00:15                          5-10
# 16           27/07       00:15         00:15                          5-10
# 16           28/07       00:20         00:20                          5-10
# 17           16/08       10:45         11:15                           180
# 17           17/08       10:55         11:15                           180
# 18           16/08       11:00         12:30                        60- 90
# 18           17/08       11:00         01:30                            60
# 19           06/08       00:00         00:00                             0
# 19           07/08       00:00         00:00                             5
# 19           08/08       23:00         23:10                             5
# 21           08/10       23:15         23:15                            15
# 21           09/10       00:15         00:45                            30
#
#             Wake up time Time to get up Quality of Sleep How Refreshed  \
# Participant
# 1                  07:00          07:00             Poor      Somewhat
# 1                  06:30          06:30             Fair      Somewhat
# 1                  07:00          07:00             Fair      Somewhat
# 14                 08:20          08:25             Fair     Refreshed
# 14                 07:55          08:00             Fair     Refreshed
# 14                 08:50          08:50             Good     Refreshed
# 14                 08:40          10:00        Very Good     Refreshed
# 14                 10:00          10:15        Very Good     Refreshed
# 14                 08:20          08:20             Good     Refreshed
# 14                 08:00          08:00        Very Good      Somewhat
# 14                 08:10          08:10        Very Good     Refreshed
# 14                 08:10          08:10        Very Good     Refreshed
# 14                 08:00          08:00        Very Good     Refreshed
# 14                 09:30          10:00             Good      Somewhat
# 14                 10:00          10:00             Fair      Somewhat
# 14                 08:00          08:30             Fair      Somewhat
# 14                 08:40          09:00             Fair      Somewhat
# 14                 08:40          08:50             Good      Somewhat
# 14                 09:00          09:00             Good      Somewhat
# 14                 09:00          09:00             Good      Somewhat
# 14                 06:30          07:00             Good      Somewhat
# 14                 07:30          08:00             Good          Very
# 15                 06:20          06:28             Fair      Slightly
# 15                 06:30          06:37             Good      Somewhat
# 15                 07:00          07:06             Fair      Somewhat
# 15                 06:30          06:30             Poor      Slightly
# 16                 05:00          08:20             Poor      Slightly
# 16                 08:00          08:00             Good     Refreshed
# 16                 05:00          08:00             Fair      Somewhat
# 17                 06:00          07:50             Poor      Somewhat
# 17                 06:00          07:20             Poor      Somewhat
# 18                 10:40          11:00             Fair     Refreshed
# 18                 08:45          08:55             Good     Refreshed
# 19                 10:00          10:10             Good     Refreshed
# 19                 08:00          08:10        Very Good     Refreshed
# 19                 08:00          08:10             Good      Somewhat
# 21                 08:00          08:20             Good     Refreshed
# 21                 08:00          08:30             Fair      Somewhat
#
#             Normal Night                                           Comments
# Participant
# 1                    Yes                                                  -
# 1                    Yes                                                  -
# 1                    Yes                                                  -
# 14                    No           woken by very noisy birds in the morning
# 14                    No                    Car alarm went off in the night
# 14                   Yes                                                NaN
# 14                   Yes                                                NaN
# 14                   Yes                                                NaN
# 14                   Yes                                                NaN
# 14                   Yes                                                NaN
# 14                   Yes                                                NaN
# 14                   Yes                                                NaN
# 14                   Yes                                                NaN
# 14                   Yes                                                NaN
# 14                    No                          It was loud on the street
# 14                    No                          It was loud on the street
# 14                    No                                Couldn't sleep well
# 14                   Yes                                                NaN
# 14                   Yes                                                NaN
# 14                   Yes                                                NaN
# 14                   Yes                                                NaN
# 14                   Yes                                                NaN
# 15                    No                                                NaN
# 15                  Yes                                                 NaN
# 15                   Yes                                                NaN
# 15                    No                                                NaN
# 16                    No  The bed was harder than I'm used to and it hur...
# 16                   Yes  Used two pillows and an airplane sleeping mat ...
# 16                   Yes                            Forgot the sleeping mat
# 17                    No  I got very hot and opened the window. Suffered...
# 17                    No                 No idea why - Just didn't drop off
# 18                   Yes                                                NaN
# 18                   Yes                                                NaN
# 19                   Yes                                                NaN
# 19                   Yes                                                NaN
# 19                   Yes                                                NaN
# 21                   Yes                                                NaN
# 21                    No  Normally I sleep very well and I awoke several...

# %%
# convert 'Quality of Sleep' to numeric labels
allLabels = []
for d in data['Quality of Sleep']:
    if(d == 'Poor'):
        allLabels.append(0)
    elif(d == 'Fair'):
        allLabels.append(1)
    elif(d == 'Good'):
        allLabels.append(2)
    else:
        allLabels.append(3)

# get only labels for trainingData
labels = []
for i in range(len(allFeatures)):
    labels.append(allLabels[i])

# %%
predictions = []

for i,n in enumerate(normalisedFeatures):
    feature = np.delete(normalisedFeatures, i, axis=0)
    lbl = np.delete(labels, i)
    knn = KNeighborsClassifier(n_neighbors=1)
    knn.fit(feature, lbl)
    predict = knn.predict(normalisedFeatures[i])
    predictions.append(predict)
# Out:
# //anaconda/lib/python3.6/site-packages/sklearn/utils/validation.py:395: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
# //anaconda/lib/python3.6/site-packages/sklearn/utils/validation.py:395: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
# //anaconda/lib/python3.6/site-packages/sklearn/utils/validation.py:395: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
# //anaconda/lib/python3.6/site-packages/sklearn/utils/validation.py:395: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
# //anaconda/lib/python3.6/site-packages/sklearn/utils/validation.py:395: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
# //anaconda/lib/python3.6/site-packages/sklearn/utils/validation.py:395: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
# //anaconda/lib/python3.6/site-packages/sklearn/utils/validation.py:395: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
# //anaconda/lib/python3.6/site-packages/sklearn/utils/validation.py:395: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
# //anaconda/lib/python3.6/site-packages/sklearn/utils/validation.py:395: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)

# %%
# make PCA (dimensionality reduction) to 3D and plot
# with TRUE labels
from mpl_toolkits.mplot3d import Axes3D
fig = plt.figure(1, figsize=(4, 3))
plt.clf()
ax = Axes3D(fig, rect=[0, 0, .95, 1], elev=48, azim=134)

plt.cla()
pca = decomposition.PCA(n_components=3)
pca.fit(allFeatures)
X = pca.transform(allFeatures)

# only needed for non int labels (I think)
# y = np.choose(label, [1, 2, 0]).astype(np.float)

pca_plot = ax.scatter(X[:, 0], X[:, 1], X[:, 2], c=labels, cmap='spring') # alt. cmap='spring'
fig.colorbar(pca_plot, ax=ax)

ax.w_xaxis.set_ticklabels([])
ax.w_yaxis.set_ticklabels([])
ax.w_zaxis.set_ticklabels([])
plt.savefig('classified')
plt.show()

# %%
# make PCA (dimensionality reduction) to 3D and plot
# with PREDICTED labels
from mpl_toolkits.mplot3d import Axes3D
fig = plt.figure(1, figsize=(4, 3))
plt.clf()
ax = Axes3D(fig, rect=[0, 0, .95, 1], elev=48, azim=134)

plt.cla()
pca = decomposition.PCA(n_components=3)
pca.fit(allFeatures)
X = pca.transform(allFeatures)

# only needed for non int labels (I think)
# y = np.choose(label, [1, 2, 0]).astype(np.float)

pca_plot = ax.scatter(X[:, 0], X[:, 1], X[:, 2], c=predictions, cmap='spring') # alt. cmap='spring'
fig.colorbar(pca_plot, ax=ax)

ax.w_xaxis.set_ticklabels([])
ax.w_yaxis.set_ticklabels([])
ax.w_zaxis.set_ticklabels([])
plt.savefig('classified2', dpi=500)
plt.show()

# %%
def reverseMap(label):
    if(label == 0):
        return 'Poor'
    if(label == 1):
        return 'Fair'
    if(label == 2):
        return 'Good'
    else:
        return 'Very good'

# %%
for i,n in enumerate(labels):
    pred = predictions[i][0]
    myStr = 'hello'
    if(not(pred == n)):
        myStr = '. You fucked up!'
    else:
        myStr = '. Well done! (lucky..)'
    print('In night ' + str(i) + ' the quality ' + reverseMap(n) + ' is predicted as ' + reverseMap(pred) + myStr)
# Out:
# In night 0 the quality Poor is predicted as Very good. You fucked up!
# In night 1 the quality Fair is predicted as Poor. You fucked up!
# In night 2 the quality Fair is predicted as Fair. Well done! (lucky..)
# In night 3 the quality Fair is predicted as Fair. Well done! (lucky..)
# In night 4 the quality Fair is predicted as Fair. Well done! (lucky..)
# In night 5 the quality Good is predicted as Very good. You fucked up!
# In night 6 the quality Very good is predicted as Good. You fucked up!
# In night 7 the quality Very good is predicted as Good. You fucked up!
# In night 8 the quality Good is predicted as Very good. You fucked up!

# %%
predictions, labels
# Out:
# ([array([3]),
#   array([0]),
#   array([1]),
#   array([1]),
#   array([1]),
#   array([3]),
#   array([2]),
#   array([2]),
#   array([3])],
#  [0, 1, 1, 1, 1, 2, 3, 3, 2])
